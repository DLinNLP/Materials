# %% [markdown]
# Prerequisities: Access data in google drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import torch
from torch import nn, optim
import numpy
import torch.utils.data as tud

# %% [markdown]
# Helper functions for evaluating model

# %%
def get_accuracy(hypos, refs):
        assert(len(hypos) == len(refs))
        correct = 0
        print("hypos", numpy.bincount(numpy.array(hypos)))
        for h, r in zip(hypos, refs):
                if h == r:
                        correct += 1
        total = len(refs)
        return correct * 100 / total

def evaluate_model(data_loader, model, set_name, sort=False):
        results_dev = []
        labels_dev = []
        for data in data_loader:
                if sort:  # needed for LSTM with pack_padded_sequences
                        x, l, y = sort_by_length(data['x'], data['length'], 
                                                 data['y'])
                else:
                        x, l, y = data['x'], data['length'], data['y']
                result = model(x, l)
                argmax = result.argmax(dim=1).cpu().numpy()
                results_dev.extend(list(argmax))
                labels_dev.extend(list(y.cpu().numpy()))
        accuracy = get_accuracy(results_dev, labels_dev)
        print("accuracy on " + set_name + ":", accuracy)

# %% [markdown]
# Dataset class for hate speech dataset

# %%
class HateSpeechDataset(tud.Dataset):
        def __init__(self, filename_data, filename_length, filename_labels):
                self.data_np = numpy.load(filename_data)
                self.length_np = numpy.load(filename_length)
                self.labels_np = numpy.load(filename_labels)
                self.data = torch.tensor(self.data_np).long().cuda()
                self.length = torch.tensor(self.length_np).long().cuda()
                self.labels = torch.tensor(self.labels_np).long().cuda()

        def __len__(self):
                return len(self.data_np)

        def __getitem__(self, idx):
                return {'x': self.data[idx], 
                        'length': self.length[idx], 
                        'y': self.labels[idx]}

# %% [markdown]
# Model: hate speech detector

# %%
class HateSpeechDetector(nn.Module):

  def __init__(self, options):
    super(HateSpeechDetector, self).__init__()
    # TASK A: add your layers here

  def forward(self, x, length):
    # TASK A: add which calculations you need to do to get output softmax scores
    return scores

# %% [markdown]
# Training the model

# %%
# loading data
path = "/content/drive/My Drive/summerschool_data/"
train_set = HateSpeechDataset(path + "train.data2.npy", 
                              path + "train.length.npy", 
                              path + "train.labels.npy")
dev_set = HateSpeechDataset(path + "dev.data2.npy", 
                            path + "dev.length.npy", 
                            path + "dev.labels.npy")
test_set = HateSpeechDataset(path + "test.data2.npy", 
                             path + "test.length.npy", 
                             path + "test.labels.npy")

# setting hyperparameters
options = {
                'vocab_size': 23078,
                'emb_dim': 300,
                'num_labels': 3,
                'num_epochs': 20,
                'batch_size': 100
          }

# TASK B: initialize model and define loss function and optimizer here
model = 
model.cuda()  # do this before instantiating the optimizer
loss_function = 
optimizer = 

# training loop
train_loader = tud.DataLoader(train_set, batch_size=options['batch_size'], 
                              shuffle=True)
dev_loader = tud.DataLoader(dev_set, batch_size=options['batch_size'])
test_loader = tud.DataLoader(test_set, batch_size=options['batch_size'])

for epoch in range(options['num_epochs']):
        print("training epoch", epoch + 1)
        # train model on training data
        for data in train_loader:
                # TASK C: add training step here

        # TASK C: add evaluation on dev data here

# TASK C: add evaluation on test data here
# Out:
# embedding.weight
# linear.weight
# linear.bias
# training epoch 1
# hypos [   21 19040  1722]
# accuracy on train: 82.65409228696531
# hypos [   3 1839  158]
# accuracy on dev: 81.55
# training epoch 2
# hypos [   81 17845  2857]
# accuracy on train: 87.2203243035173
# hypos [   6 1735  259]
# accuracy on dev: 85.1
# training epoch 3
# hypos [  150 17354  3279]
# accuracy on train: 89.62132512149353
# hypos [  18 1690  292]
# accuracy on dev: 87.0
# training epoch 4
# hypos [  223 17237  3323]
# accuracy on train: 90.69912909589569
# hypos [  33 1679  288]
# accuracy on dev: 87.65
# training epoch 5
# hypos [  216 16849  3718]
# accuracy on train: 91.73362844632632
# hypos [  32 1635  333]
# accuracy on dev: 88.7
# training epoch 6
# hypos [  237 16915  3631]
# accuracy on train: 92.37357455612761
# hypos [  34 1645  321]
# accuracy on dev: 88.6
# training epoch 7
# hypos [  303 16898  3582]
# accuracy on train: 93.07126016455757
# hypos [  41 1646  313]
# accuracy on dev: 89.0
# training epoch 8
# hypos [  360 16844  3579]
# accuracy on train: 93.54279940335852
# hypos [  45 1635  320]
# accuracy on dev: 88.95
# training epoch 9
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-6e3103ebefe5> in <module>()
#      43                 loss = loss_function(scores, labels)
#      44                 loss.backward()
# ---> 45                 optimizer.step()
#      46
#      47         evaluate_model(train_loader, model, "train")
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/adam.py in step(self, closure)
#      92                 # Decay the first and second moment running average coefficient
#      93                 exp_avg.mul_(beta1).add_(1 - beta1, grad)
# ---> 94                 exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#      95                 if amsgrad:
#      96                     # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:
